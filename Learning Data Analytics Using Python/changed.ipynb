# %%
import numpy as np
import pandas as pd

# %%
dat = pd.read_csv("Customer_dim.csv")

# %%
dat
# Out:
#                         Timestamp Participant_ID  Gender Nationality  Age  \
# 0     2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1     2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2     2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3     2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4     2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
# ..                            ...            ...     ...         ...  ...
# 283   2019/05/10 9:24:00 AM GMT+8         FPS284    Male      Indian   27
# 284   2019/05/10 9:32:54 AM GMT+8         FPS285    Male      Indian   24
# 285  2019/05/10 12:09:17 PM GMT+8         FPS286    Male      Indian   25
# 286  2019/05/10 12:52:17 PM GMT+8         FPS287    Male      Indian   27
# 287  2019/05/10 12:55:42 PM GMT+8         FPS288    Male      Indian   27
#
#                  Food              Juice Dessert
# ...

# %%
#df = pd.DataFrame(data)
 
# Define new data for additional columns
#age = [22, 25, 23, 24]
#state = ['NCT', 'Karnataka', 'Tamil Nadu', 'Bihar']
 
# Add multiple columns using dictionary assignment
#new_data = {'Age': age, 'State': state }
#df = df.assign(**new_data)
 
#NAprint(df)

# %%
Nombres = pd.read_excel("/Users/victormorenorequena/Desktop/My_Projects/trueque nombres.xlsx")

# %%
Nombres["Names"]
# Out:
# 0      José Luis Palomino
# 1          Nicolás Freire
# 2           Miguel Torrén
# 3          Matías Caruzzo
# 4              Juan Sabia
#               ...
# 283          Agustín Aleo
# 284           Enzo Ybáñez
# 285            Román Vega
# 286         Luciano Gómez
# 287     Jonathan Sandoval
# Name: Names, Length: 288, dtype: object

# %%
combined = pd.merge(dat, Nombres, how="inner", on="Participant_ID")
combined
# Out:
#                         Timestamp Participant_ID  Gender Nationality  Age  \
# 0     2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1     2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2     2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3     2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4     2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
# ..                            ...            ...     ...         ...  ...
# 283   2019/05/10 9:24:00 AM GMT+8         FPS284    Male      Indian   27
# 284   2019/05/10 9:32:54 AM GMT+8         FPS285    Male      Indian   24
# 285  2019/05/10 12:09:17 PM GMT+8         FPS286    Male      Indian   25
# 286  2019/05/10 12:52:17 PM GMT+8         FPS287    Male      Indian   27
# 287  2019/05/10 12:55:42 PM GMT+8         FPS288    Male      Indian   27
#
#                  Food              Juice Dessert               Names
# ...

# %%
combined.to_csv('Customer_ID_FINAL.csv', index=False)
